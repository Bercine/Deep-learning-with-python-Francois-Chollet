# %% [markdown]
# <a href="https://colab.research.google.com/github/Bercine/Deep-learning-with-python-Francois-Chollet/blob/main/chap8_deep_learning_for_computer_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Listing 8.1 Instantiating a small convnet

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
inputs = keras.Input(shape=(28, 28, 1))

# %%
x = layers.Conv2D(filters=32, kernel_size=3, activation='relu')(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x = layers.Flatten()(x)

# %%
outputs = layers.Dense(10, activation='softmax')(x)

# %%
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# #Listing 8.2 Displaying the model’s summary

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        11,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,202 (407.04 KB)
#  Trainable params: 104,202 (407.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Listing 8.3 Training the convnet on MNIST images

# %%
from tensorflow.keras.datasets import mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images= test_images.astype('float32') / 255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model.compile(
    optimizer='rmsprop',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    train_images, train_labels,
    epochs=5, batch_size=64
)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9503 - loss: 0.1622
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9862 - loss: 0.0438
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9902 - loss: 0.0317
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9928 - loss: 0.0232
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9944 - loss: 0.0185

# %% [markdown]
# #Listing 8.4 Evaluating the convnet

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy : {test_acc:.3f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9925 - loss: 0.0228
# Test accuracy : 0.993

# %% [markdown]
# #Listing 8.5 An incorrectly structured convnet missing its max-pooling layers

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation='relu')(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation='relu')(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation='softmax')(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 22, 22, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 61952)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │       619,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 712,202 (2.72 MB)
#  Trainable params: 712,202 (2.72 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Training a convnet from scratch on a small dataset

# %%
# !wget https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip
# Out:
# --2026-06-15 17:04:13--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip
# Resolving download.microsoft.com (download.microsoft.com)... 184.28.149.199, 2600:1406:5e00:392::317f, 2600:1406:5e00:389::317f
# Connecting to download.microsoft.com (download.microsoft.com)|184.28.149.199|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824887076 (787M) [application/octet-stream]
# Saving to: ‘kagglecatsanddogs_5340.zip’
#
# kagglecatsanddogs_5 100%[===================>] 786.67M  99.2MB/s    in 9.0s
#
# 2026-06-15 17:04:22 (87.8 MB/s) - ‘kagglecatsanddogs_5340.zip’ saved [824887076/824887076]

# %%
import zipfile
with zipfile.ZipFile('kagglecatsanddogs_5340.zip', 'r') as z:
    z.extractall('/content/')

# %%
import os
from pathlib import Path

original_dir = Path('PetImages')

for folder in ('Cat', 'Dog'):
    for f in (original_dir / folder).glob('*.jpg'):
        try:
            with open(f, 'rb') as fobj:
                if b"JFIF" not in fobj.peek(10):
                    os.remove(f)
        except:
            os.remove(f)

# %%
import shutil

new_base_dir = Path('cats_vs_dogs_small')

def make_subset(subset_name, start_index, end_index):
    for category in ('Cat', 'Dog'):
        src_folder = original_dir / category
        dst_folder = new_base_dir / subset_name / category.lower()
        dst_folder.mkdir(parents=True, exist_ok=True)

        # Lister toutes les images existantes, triées
        images = sorted(src_folder.glob('*.jpg'))

        # Prendre la tranche start_index à end_index
        for i, src in enumerate(images[start_index:end_index]):
            dst = dst_folder / f"{category.lower()}.{i}.jpg"
            shutil.copyfile(src, dst)

# %%
make_subset('train', 0, 1000)
make_subset('validation', 1000, 1500)
make_subset('test', 1500, 2500)

# %% [markdown]
# #Listing 8.7 Instantiating a small convnet for dogs vs. cats classification

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation='relu')(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        12,545 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Listing 8.8 Configuring the model for training

# %%
model.compile(
    optimizer='rmsprop',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# #Listing 8.9 Using image_dataset_from_directory to read images

# %%
from tensorflow.keras.utils import  image_dataset_from_directory

# %%
train_dataset = image_dataset_from_directory(new_base_dir / 'train',
                                             image_size=(180, 180),
                                             batch_size=32)
validation_dataset = image_dataset_from_directory(new_base_dir / 'validation',
                                                  image_size=(180, 180),
                                                  batch_size=32)
test_dataset = image_dataset_from_directory(new_base_dir / 'test',
                                            image_size=(180, 180),
                                            batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
# Compter les images d'origine
from pathlib import Path

original_dir = Path('PetImages')
print("Chats :", len(list((original_dir / 'Cat').glob('*.jpg'))))
print("Chiens :", len(list((original_dir / 'Dog').glob('*.jpg'))))
# Out:
# Chats : 11741
# Chiens : 11669

# %% [markdown]
# #Listing 8.10 Displaying the shapes of the data and labels yielded by the Dataset

# %%
for data_batch, labels_batch in train_dataset:
  print("data batch shape : ", data_batch.shape)
  print("labels batch shape : ", labels_batch.shape)
  break
# Out:
# data batch shape :  (32, 180, 180, 3)
# labels batch shape :  (32,)

# %% [markdown]
# #Listing 8.11 Fitting the model using a Dataset

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='convnet_from_scratch.keras',
        save_best_only=True,
        monitor='val_loss'
    )
]

# %%
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5215 - loss: 0.7050
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_499/609131337.py in <cell line: 0>()
# ----> 1 history = model.fit(
#       2     train_dataset,
#       3     epochs=30,
#       4     validation_data=validation_dataset,
#       5     callbacks=callbacks
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #Listing 8.12 Displaying curves of loss and accuracy during training

# %%
import matplotlib.pyplot as plt
accuracy = history.history['accuracy']
loss = history.history['loss']
val_accuracy = history.history['val_accuracy']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validatioin accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validatioin loss')
plt.legend()
plt.show()

# %% [markdown]
# #Listing 8.13 Evaluating the model on the test set

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f'Test accuraccy : {test_acc:.3f}')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7235 - loss: 1.9214
# Test accuraccy : 0.724

# %% [markdown]
# #Listing 8.14 Define a data augmentation stage to add to an image model

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# %% [markdown]
# #Listing 8.15 Displaying some randomly augmented training images

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype('uint8'))
    plt.axis('off')

# %% [markdown]
# #Listing 8.16 Defining a new convnet that includes image augmentation and dropout

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model2 = keras.Model(inputs=inputs, outputs=outputs)
model2.compile(loss="binary_crossentropy",
      optimizer="rmsprop",
      metrics=["accuracy"])

# %% [markdown]
# #Listing 8.17 Training the regularized convnet

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='convnet_from_scratch_with_augmentation.keras',
        save_best_only=True,
        monitor='val_loss'
    )
]
history = model2.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.5180 - loss: 0.6982 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.5110 - loss: 0.6942 - val_accuracy: 0.5000 - val_loss: 0.6933
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.5405 - loss: 0.6901 - val_accuracy: 0.5350 - val_loss: 0.6863
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.5840 - loss: 0.7048 - val_accuracy: 0.6160 - val_loss: 0.6545
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.6260 - loss: 0.6461 - val_accuracy: 0.6630 - val_loss: 0.6204
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.6300 - loss: 0.6514 - val_accuracy: 0.6800 - val_loss: 0.6068
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.6515 - loss: 0.6307 - val_accuracy: 0.6630 - val_loss: 0.6073
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.6530 - loss: 0.6228 - val_accuracy: 0.6820 - val_loss: 0.5943
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.6700 - loss: 0.6051 - val_accuracy: 0.6940 - val_loss: 0.5739
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.6735 - loss: 0.6050 - val_accuracy: 0.7000 - val_loss: 0.5686
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.6885 - loss: 0.5863 - val_accuracy: 0.7120 - val_loss: 0.5510
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.6910 - loss: 0.5856 - val_accuracy: 0.6510 - val_loss: 0.6172
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.6890 - loss: 0.5856 - val_accuracy: 0.7430 - val_loss: 0.5124
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.7240 - loss: 0.5551 - val_accuracy: 0.7200 - val_loss: 0.5328
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.7180 - loss: 0.5493 - val_accuracy: 0.7320 - val_loss: 0.5190
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.7345 - loss: 0.5384 - val_accuracy: 0.7150 - val_loss: 0.5442
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.7365 - loss: 0.5310 - val_accuracy: 0.6850 - val_loss: 0.5800
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.7440 - loss: 0.5236 - val_accuracy: 0.7650 - val_loss: 0.5025
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.7450 - loss: 0.5071 - val_accuracy: 0.7530 - val_loss: 0.4956
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.7660 - loss: 0.4915 - val_accuracy: 0.7250 - val_loss: 0.5721
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.7695 - loss: 0.4810 - val_accuracy: 0.7980 - val_loss: 0.4452
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7700 - loss: 0.4613 - val_accuracy: 0.7800 - val_loss: 0.4730
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.7875 - loss: 0.4471 - val_accuracy: 0.7850 - val_loss: 0.4680
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.7890 - loss: 0.4531 - val_accuracy: 0.7740 - val_loss: 0.4976
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8125 - loss: 0.4276 - val_accuracy: 0.7600 - val_loss: 0.4934
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.7990 - loss: 0.4268 - val_accuracy: 0.7770 - val_loss: 0.4596
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.8165 - loss: 0.4180 - val_accuracy: 0.8020 - val_loss: 0.4464
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.8070 - loss: 0.4218 - val_accuracy: 0.6630 - val_loss: 0.7215
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8115 - loss: 0.4116 - val_accuracy: 0.8070 - val_loss: 0.4318
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8230 - loss: 0.4049 - val_accuracy: 0.7910 - val_loss: 0.4433
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8205 - loss: 0.4036 - val_accuracy: 0.7240 - val_loss: 0.5458
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.8250 - loss: 0.4015 - val_accuracy: 0.7910 - val_loss: 0.5464
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.8245 - loss: 0.3868 - val_accuracy: 0.8260 - val_loss: 0.3743
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.8205 - loss: 0.3836 - val_accuracy: 0.8030 - val_loss: 0.4415
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.8360 - loss: 0.3697 - val_accuracy: 0.8180 - val_loss: 0.3793
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8380 - loss: 0.3514 - val_accuracy: 0.8140 - val_loss: 0.4483
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.8425 - loss: 0.3450 - val_accuracy: 0.8340 - val_loss: 0.4387
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8410 - loss: 0.3590 - val_accuracy: 0.8460 - val_loss: 0.3723
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8560 - loss: 0.3390 - val_accuracy: 0.8190 - val_loss: 0.4346
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.8525 - loss: 0.3377 - val_accuracy: 0.8120 - val_loss: 0.4207
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8595 - loss: 0.3221 - val_accuracy: 0.8160 - val_loss: 0.4315
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.8690 - loss: 0.3206 - val_accuracy: 0.8410 - val_loss: 0.3825
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.8615 - loss: 0.3112 - val_accuracy: 0.8230 - val_loss: 0.4142
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8570 - loss: 0.3117 - val_accuracy: 0.8190 - val_loss: 0.3949
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8725 - loss: 0.2950 - val_accuracy: 0.8350 - val_loss: 0.3813
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.8745 - loss: 0.2896 - val_accuracy: 0.8280 - val_loss: 0.4427
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8750 - loss: 0.2896 - val_accuracy: 0.7720 - val_loss: 0.6874
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.8770 - loss: 0.2940 - val_accuracy: 0.8090 - val_loss: 0.5282
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.8905 - loss: 0.2669 - val_accuracy: 0.8370 - val_loss: 0.4041
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.8875 - loss: 0.2677 - val_accuracy: 0.6920 - val_loss: 0.8099
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8790 - loss: 0.2764 - val_accuracy: 0.8100 - val_loss: 0.4805
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.8870 - loss: 0.2705 - val_accuracy: 0.8080 - val_loss: 0.4814
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8975 - loss: 0.2491 - val_accuracy: 0.7480 - val_loss: 0.5540
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8995 - loss: 0.2428 - val_accuracy: 0.8020 - val_loss: 0.5017
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8955 - loss: 0.2402 - val_accuracy: 0.8120 - val_loss: 0.5612
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.9015 - loss: 0.2436 - val_accuracy: 0.7940 - val_loss: 0.5743
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9005 - loss: 0.2442 - val_accuracy: 0.8340 - val_loss: 0.4163
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.8970 - loss: 0.2577 - val_accuracy: 0.7680 - val_loss: 0.6906
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9090 - loss: 0.2126 - val_accuracy: 0.8540 - val_loss: 0.3847
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9010 - loss: 0.2351 - val_accuracy: 0.8390 - val_loss: 0.4669
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.9140 - loss: 0.2216 - val_accuracy: 0.7860 - val_loss: 0.7425
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9125 - loss: 0.2224 - val_accuracy: 0.8050 - val_loss: 0.7635
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9110 - loss: 0.2195 - val_accuracy: 0.8540 - val_loss: 0.4271
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9155 - loss: 0.2063 - val_accuracy: 0.8210 - val_loss: 0.7503
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - accuracy: 0.9150 - loss: 0.2288 - val_accuracy: 0.7750 - val_loss: 0.5759
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9100 - loss: 0.2151 - val_accuracy: 0.8590 - val_loss: 0.3870
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.9295 - loss: 0.1899 - val_accuracy: 0.8460 - val_loss: 0.5002
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9055 - loss: 0.2329 - val_accuracy: 0.8320 - val_loss: 0.4294
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9095 - loss: 0.2131 - val_accuracy: 0.8100 - val_loss: 0.4733
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.9405 - loss: 0.1767 - val_accuracy: 0.8240 - val_loss: 0.6948
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9205 - loss: 0.2149 - val_accuracy: 0.8480 - val_loss: 0.4456
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.9310 - loss: 0.1870 - val_accuracy: 0.8540 - val_loss: 0.4944
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.9265 - loss: 0.1875 - val_accuracy: 0.8350 - val_loss: 0.5010
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9280 - loss: 0.1871 - val_accuracy: 0.7830 - val_loss: 0.7188
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.9210 - loss: 0.2023 - val_accuracy: 0.8500 - val_loss: 0.4713
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9300 - loss: 0.1930 - val_accuracy: 0.8150 - val_loss: 0.5221
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9325 - loss: 0.1790 - val_accuracy: 0.8550 - val_loss: 0.4331
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9310 - loss: 0.1827 - val_accuracy: 0.8560 - val_loss: 0.5160
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.9290 - loss: 0.1883 - val_accuracy: 0.8170 - val_loss: 0.6483
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.9305 - loss: 0.1760 - val_accuracy: 0.8580 - val_loss: 0.4836
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.9280 - loss: 0.1843 - val_accuracy: 0.8490 - val_loss: 0.5849
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.9295 - loss: 0.1864 - val_accuracy: 0.8300 - val_loss: 0.6485
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9355 - loss: 0.1693 - val_accuracy: 0.8390 - val_loss: 0.5613
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.9345 - loss: 0.1838 - val_accuracy: 0.8550 - val_loss: 0.5544
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9380 - loss: 0.1651 - val_accuracy: 0.8610 - val_loss: 0.5306
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9300 - loss: 0.1723 - val_accuracy: 0.8830 - val_loss: 0.4957
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9350 - loss: 0.1845 - val_accuracy: 0.8330 - val_loss: 0.5344
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9425 - loss: 0.1633 - val_accuracy: 0.8400 - val_loss: 0.6344
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9355 - loss: 0.1798 - val_accuracy: 0.8530 - val_loss: 0.4556
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9420 - loss: 0.1445 - val_accuracy: 0.8530 - val_loss: 0.4508
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.9465 - loss: 0.1472 - val_accuracy: 0.8310 - val_loss: 0.9296
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.9355 - loss: 0.1707 - val_accuracy: 0.8580 - val_loss: 0.5782
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9425 - loss: 0.1718 - val_accuracy: 0.8340 - val_loss: 0.4813
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9345 - loss: 0.1838 - val_accuracy: 0.8690 - val_loss: 0.4768
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9520 - loss: 0.1372 - val_accuracy: 0.8360 - val_loss: 0.5766
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9435 - loss: 0.1521 - val_accuracy: 0.8350 - val_loss: 0.7429
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.9470 - loss: 0.1364 - val_accuracy: 0.8680 - val_loss: 0.5941
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9480 - loss: 0.1612 - val_accuracy: 0.8220 - val_loss: 0.8259
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9560 - loss: 0.1297 - val_accuracy: 0.8660 - val_loss: 0.7143
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.9525 - loss: 0.1590 - val_accuracy: 0.7950 - val_loss: 0.9020

# %%
import matplotlib.pyplot as plt
accuracy = history.history['accuracy']
loss = history.history['loss']
val_accuracy = history.history['val_accuracy']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validatioin accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validatioin loss')
plt.legend()
plt.show()

# %% [markdown]
# #Listing 8.18 Evaluating the model on the test set

# %%
test_model = keras.models.load_model('convnet_from_scratch_with_augmentation.keras')
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f'Test accuracy : {test_acc:.3f}')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8330 - loss: 0.4159
# Test accuracy : 0.833

# %% [markdown]
# #Listing 8.19 Instantiating the VGG16 convolutional base

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights = 'imagenet',
    include_top=False,
    input_shape=(180, 180, 3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 180, 180, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 180, 180, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 90, 90, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 90, 90, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 90, 90, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 45, 45, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 45, 45, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 22, 22, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 22, 22, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 11, 11, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 5, 5, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Listing 8.20 Extracting the VGG16 features and corresponding labels

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
def get_features_and_labels(dataset) :
  all_features = []
  all_labels = []
  for images, labels in dataset:
    preprocessed_images = keras.applications.vgg16.preprocess_input(images)
    features = conv_base.predict(preprocessed_images)
    all_features.append(features)
    all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step

# %%
train_features.shape
# Out:
# (32, 5, 5, 512)

# %% [markdown]
# #Listing 8.21 Defining and training the densely connected classifier

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model3  = keras.Model(inputs, outputs)

model3.compile(loss='binary_crossentropy',
               optimizer='rmsprop',
               metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='feature_extraction.keras',
        save_best_only=True,
        monitor='val_loss'
    )
]

history = model3.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5000 - loss: 19.3790 - val_accuracy: 0.4375 - val_loss: 283.9112
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.6562 - loss: 115.1503 - val_accuracy: 0.7188 - val_loss: 48.4538
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8750 - loss: 31.4158 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 5.3369e-23 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 1.1509e-23 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 1.6239e-25 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 3.0808e-25 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 7.1386e-25 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 6.6745e-14 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 9.1902e-22 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9375 - val_loss: 17.5680

# %% [markdown]
# #Listing 8.22 Plotting the results

# %%
import matplotlib.pyplot as plt
accuracy = history.history['accuracy']
loss = history.history['loss']
val_accuracy = history.history['val_accuracy']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validatioin accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validatioin loss')
plt.legend()
plt.show()

# %%
model3.evaluate(test_features, test_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8750 - loss: 16.4468
# [16.446840286254883, 0.875]

# %% [markdown]
# #Listing 8.23 Instantiating and freezing the VGG16 convolutional base

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights='imagenet',
    include_top=False
)
conv_base.trainable = False

# %% [markdown]
# #Listing 8.24 Printing the list of trainable weights before and after freezing

# %%
conv_base.trainable = True

# %%
 print("This is the number of trainable weights "
"before freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights before freezing the conv base: 26

# %%
conv_base.trainable = False

# %%
 print("This is the number of trainable weights "
"after freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights after freezing the conv base: 0

# %% [markdown]
# #Listing 8.25 Adding a data augmentation stage and a classifier to the convolutional base

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2)
])

# %%
inputs = keras.Input(shape=(180, 180 ,3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model4 = keras.Model(inputs, outputs)
model4.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='feature_extraction_with_data_augmentation.keras',
        save_best_only=True,
        monitor='val_loss'
    )
]

# %%
history = model4.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 16s 195ms/step - accuracy: 0.8905 - loss: 21.6130 - val_accuracy: 0.9600 - val_loss: 8.0928
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 149ms/step - accuracy: 0.9410 - loss: 7.6545 - val_accuracy: 0.9530 - val_loss: 9.3199
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 149ms/step - accuracy: 0.9515 - loss: 5.8677 - val_accuracy: 0.9650 - val_loss: 6.2108
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 139ms/step - accuracy: 0.9585 - loss: 4.2466 - val_accuracy: 0.9710 - val_loss: 6.4680
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 139ms/step - accuracy: 0.9650 - loss: 3.8560 - val_accuracy: 0.9700 - val_loss: 7.7270
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.9615 - loss: 4.1685 - val_accuracy: 0.9660 - val_loss: 6.7098
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - accuracy: 0.9700 - loss: 2.9642 - val_accuracy: 0.9670 - val_loss: 6.2958
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 140ms/step - accuracy: 0.9690 - loss: 3.0191 - val_accuracy: 0.9700 - val_loss: 6.9863
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 149ms/step - accuracy: 0.9695 - loss: 3.2897 - val_accuracy: 0.9700 - val_loss: 6.1953
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 151ms/step - accuracy: 0.9765 - loss: 2.2347 - val_accuracy: 0.9740 - val_loss: 5.1742
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9775 - loss: 1.9327 - val_accuracy: 0.9660 - val_loss: 6.3203
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9785 - loss: 2.0537 - val_accuracy: 0.9720 - val_loss: 5.7320
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.9800 - loss: 1.6685 - val_accuracy: 0.9720 - val_loss: 5.1856
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.9745 - loss: 2.0496 - val_accuracy: 0.9660 - val_loss: 6.0793
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 146ms/step - accuracy: 0.9800 - loss: 1.5154 - val_accuracy: 0.9710 - val_loss: 5.0116
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 140ms/step - accuracy: 0.9830 - loss: 1.1254 - val_accuracy: 0.9730 - val_loss: 5.0362
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - accuracy: 0.9775 - loss: 1.5990 - val_accuracy: 0.9800 - val_loss: 4.0434
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - accuracy: 0.9825 - loss: 1.0954 - val_accuracy: 0.9660 - val_loss: 4.7655
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - accuracy: 0.9825 - loss: 1.2499 - val_accuracy: 0.9730 - val_loss: 4.3408
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9810 - loss: 1.3261 - val_accuracy: 0.9700 - val_loss: 4.2813
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9845 - loss: 1.0212 - val_accuracy: 0.9740 - val_loss: 4.1714
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9830 - loss: 1.0552 - val_accuracy: 0.9560 - val_loss: 6.5130
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9825 - loss: 1.1527 - val_accuracy: 0.9780 - val_loss: 4.1283
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 148ms/step - accuracy: 0.9815 - loss: 1.3665 - val_accuracy: 0.9730 - val_loss: 3.9391
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 145ms/step - accuracy: 0.9780 - loss: 1.4368 - val_accuracy: 0.9710 - val_loss: 3.8437
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 146ms/step - accuracy: 0.9860 - loss: 0.8713 - val_accuracy: 0.9760 - val_loss: 3.6760
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.9830 - loss: 0.7861 - val_accuracy: 0.9770 - val_loss: 3.9701
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9885 - loss: 0.6661 - val_accuracy: 0.9780 - val_loss: 3.8856
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9855 - loss: 0.8423 - val_accuracy: 0.9780 - val_loss: 3.6904
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - accuracy: 0.9830 - loss: 0.8671 - val_accuracy: 0.9740 - val_loss: 3.5889
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - accuracy: 0.9805 - loss: 0.9385 - val_accuracy: 0.9700 - val_loss: 4.7086
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9835 - loss: 1.0861 - val_accuracy: 0.9690 - val_loss: 4.4311
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - accuracy: 0.9845 - loss: 0.6905 - val_accuracy: 0.9710 - val_loss: 3.5019
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9855 - loss: 0.5752 - val_accuracy: 0.9690 - val_loss: 3.8934
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9885 - loss: 0.4861 - val_accuracy: 0.9740 - val_loss: 3.6619
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9865 - loss: 0.5681 - val_accuracy: 0.9760 - val_loss: 3.5774
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9860 - loss: 0.9043 - val_accuracy: 0.9760 - val_loss: 3.6376
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9855 - loss: 0.4095 - val_accuracy: 0.9620 - val_loss: 4.5621
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 146ms/step - accuracy: 0.9885 - loss: 0.4573 - val_accuracy: 0.9760 - val_loss: 3.4199
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 145ms/step - accuracy: 0.9885 - loss: 0.5792 - val_accuracy: 0.9790 - val_loss: 2.9957
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9880 - loss: 0.5411 - val_accuracy: 0.9760 - val_loss: 3.1981
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 148ms/step - accuracy: 0.9890 - loss: 0.4049 - val_accuracy: 0.9790 - val_loss: 2.9645
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9910 - loss: 0.2941 - val_accuracy: 0.9780 - val_loss: 3.1882
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 140ms/step - accuracy: 0.9895 - loss: 0.4499 - val_accuracy: 0.9780 - val_loss: 3.5501
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9905 - loss: 0.4479 - val_accuracy: 0.9750 - val_loss: 3.5116
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9905 - loss: 0.3873 - val_accuracy: 0.9780 - val_loss: 3.1598
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 147ms/step - accuracy: 0.9840 - loss: 0.7743 - val_accuracy: 0.9770 - val_loss: 2.9205
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9905 - loss: 0.3710 - val_accuracy: 0.9770 - val_loss: 3.4621
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 183ms/step - accuracy: 0.9920 - loss: 0.3921 - val_accuracy: 0.9830 - val_loss: 2.7360
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 141ms/step - accuracy: 0.9900 - loss: 0.4403 - val_accuracy: 0.9740 - val_loss: 2.9739

# %%
import matplotlib.pyplot as plt
accuracy = history.history['accuracy']
loss = history.history['loss']
val_accuracy = history.history['val_accuracy']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validatioin accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validatioin loss')
plt.legend()
plt.show()

# %% [markdown]
# #Listing 8.26 Evaluating the model on the test set

# %%
test_model = keras.models.load_model(
    'feature_extraction_with_data_augmentation.keras'
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f'Test accuracy : {test_acc:.3f}')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 93ms/step - accuracy: 0.9785 - loss: 2.1445
# Test accuracy : 0.979

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, None, None, 3)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, None, None, 64) │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, None, None, 64) │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, None, None, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, None, None,     │        73,856 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, None, None,     │       147,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, None, None,     │       295,168 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, None, None,     │       590,080 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, None, None,     │     1,180,160 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, None, None,     │     2,359,808 │
# │                                 │ 512)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, None, None,     │             0 │
# │                                 │ 512)                   │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# #Listing 8.27 Freezing all layers until the fourth from the last

# %%
conv_base.trainable = True
for  layer in conv_base.layers[:-4]:
  layer.trainable = False

# %% [markdown]
# #Listing 8.28 Fine-tuning the model

# %%
model4.compile(loss='binary_crossentropy',
               optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
               metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='fine_tuning.keras',
        save_best_only=True,
        monitor='val_loss'
        )
]

# %%
history = model4.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - accuracy: 0.9915 - loss: 0.4256 - val_accuracy: 0.9750 - val_loss: 3.0291
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.9895 - loss: 0.4499 - val_accuracy: 0.9760 - val_loss: 2.7143
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 203ms/step - accuracy: 0.9910 - loss: 0.3733 - val_accuracy: 0.9790 - val_loss: 2.6594
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 163ms/step - accuracy: 0.9895 - loss: 0.2865 - val_accuracy: 0.9790 - val_loss: 2.4743
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9920 - loss: 0.1928 - val_accuracy: 0.9780 - val_loss: 2.4821
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - accuracy: 0.9910 - loss: 0.3364 - val_accuracy: 0.9790 - val_loss: 2.4509
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9910 - loss: 0.2560 - val_accuracy: 0.9820 - val_loss: 2.4995
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9910 - loss: 0.2743 - val_accuracy: 0.9800 - val_loss: 2.4571
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9910 - loss: 0.3545 - val_accuracy: 0.9760 - val_loss: 2.7189
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 0.9915 - loss: 0.1935 - val_accuracy: 0.9830 - val_loss: 2.2881
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9930 - loss: 0.2831 - val_accuracy: 0.9780 - val_loss: 2.6549
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 12s 193ms/step - accuracy: 0.9920 - loss: 0.2596 - val_accuracy: 0.9780 - val_loss: 2.3053
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9935 - loss: 0.2138 - val_accuracy: 0.9770 - val_loss: 2.3208
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9930 - loss: 0.2176 - val_accuracy: 0.9730 - val_loss: 2.6940
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 0.9920 - loss: 0.2652 - val_accuracy: 0.9810 - val_loss: 2.0472
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9955 - loss: 0.1414 - val_accuracy: 0.9770 - val_loss: 2.2985
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9955 - loss: 0.1176 - val_accuracy: 0.9720 - val_loss: 2.8760
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9955 - loss: 0.1024 - val_accuracy: 0.9820 - val_loss: 2.0491
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9960 - loss: 0.0512 - val_accuracy: 0.9710 - val_loss: 2.9023
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9940 - loss: 0.1139 - val_accuracy: 0.9800 - val_loss: 2.0966
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9960 - loss: 0.0952 - val_accuracy: 0.9830 - val_loss: 2.1991
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9965 - loss: 0.0750 - val_accuracy: 0.9820 - val_loss: 2.3397
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9955 - loss: 0.1320 - val_accuracy: 0.9800 - val_loss: 2.4269
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9960 - loss: 0.0722 - val_accuracy: 0.9800 - val_loss: 2.4582
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9940 - loss: 0.1887 - val_accuracy: 0.9810 - val_loss: 2.4290
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9960 - loss: 0.0888 - val_accuracy: 0.9820 - val_loss: 2.2548
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9975 - loss: 0.0382 - val_accuracy: 0.9780 - val_loss: 2.5709
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9960 - loss: 0.1335 - val_accuracy: 0.9850 - val_loss: 2.1321
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 166ms/step - accuracy: 0.9970 - loss: 0.0665 - val_accuracy: 0.9830 - val_loss: 2.0139
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 167ms/step - accuracy: 0.9970 - loss: 0.0816 - val_accuracy: 0.9830 - val_loss: 2.0135

# %%
model4 = keras.models.load_model('fine_tuning.keras')
test_loss, test_acc = model4.evaluate(test_dataset)
print(f'Test accuracy : {test_acc:.3f}')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.9780 - loss: 1.8654
# Test accuracy : 0.978
